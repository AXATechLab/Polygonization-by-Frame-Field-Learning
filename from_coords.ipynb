# %%
from from_coords import *
config_path = 'weights/inria_config.json'
model_weight_path = 'weights/inria_weights.pth'
bounding_box = [[46.517913059149535, 6.560629182199143], [46.51612364430025, 6.563093295798677]]
mapbox_api_key = 'pk.eyJ1Ijoic3RhbmR1YyIsImEiOiJja21vbXdrOXUwNmE0MnFvOXVuanowMGl0In0.gvmSBOYLGavx8nhgAYTO5Q'
max_tile_nbr = 4
parcel_polygon = [[[46.51770164760618, 6.561978758097539], [46.51632117070772, 6.56094914365367], \
                 [46.51672972641991, 6.562518038992259]]]
image, buildings, parcels_polygon_xy = \
segment_buildings(config_path, model_weight_path, bounding_box, mapbox_api_key, max_tile_nbr, parcel_polygon, False)
# Out:
# /home/stan/miniconda/envs/test/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)

# %% [markdown]
# Just a notebook that tests the segment_buildings function, it gets a bounding box of latitude/longitude coordinates as input and outputs the coordinates of the contour of each building.

# %%
plt.figure(figsize=(20,20))
plt.imshow(image);
for building in buildings:
    contour = np.array(building['xy'])
    if building['area'] > 0.0:
        plt.plot(*(contour[:,0], contour[:,1]), '-o', markersize=10);
for parcel_polygon_xy in parcels_polygon_xy:
    parcel_polygon_xy = np.array(parcel_polygon_xy)
    plt.plot(*(parcel_polygon_xy[:,0], parcel_polygon_xy[:,1]), '-o', markersize=2);

# %%
colors = np.random.rand(nb_comp, 3)
plt.figure(figsize=(20,20))
plt.imshow(image)
for building in buildings:
    contour = np.array(building['xy'])
    plt.plot(*(contour[:,0], contour[:,1]), '-o', markersize=2, c=colors[building['comp'],:]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0a2f2dcc0105> in <module>
# ----> 1 colors = np.random.rand(nb_comp, 3)
#       2 plt.figure(figsize=(20,20))
#       3 plt.imshow(image)
#       4 for building in buildings:
#       5     contour = np.array(building['xy'])
#
# NameError: name 'nb_comp' is not defined

# %%
plt.figure(figsize=(20,20))
plt.imshow(image)
contour = np.array(buildings[0]['xy'])
plt.plot(*(contour[:,0], contour[:,1]), '-o', markersize=2);

# %%
buildings[1]
